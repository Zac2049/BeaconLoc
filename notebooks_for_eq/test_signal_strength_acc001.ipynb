# %%
import sys
sys.path.append('..')

from utils.common import read_beacon_coords, read_beacon_data, process_beacon_data, process_beacon_data_for_pos
import argparse
import pandas as pd

args = argparse.Namespace(beacon_coords_file='../data/beacon_coords.txt', beacon_data_file='../data/bluetoothData.txt', update_frequency=10)

actual_coords = read_beacon_coords(args.beacon_coords_file)
beacon_data = read_beacon_data(args.beacon_data_file)
print("beacon_data", beacon_data)
print(type(beacon_data))


# actual_coords_df = pd.DataFrame(actual_coords)

# # Convert beacon_data to a DataFrame
# beacon_data_df = pd.DataFrame(beacon_data)

# print("Actual Coordinates DataFrame:")
# print(actual_coords_df)
# print(actual_coords_df.dtypes)

# print("\nBeacon Data DataFrame:")
# print(beacon_data_df)
# print(beacon_data_df.dtypes)
# Out:
# beacon_data [[{'uuid': '1a040000-0000-0000-0000-000000000000', 'rssi': -60, 'accuracy': 9.027046541095386, 'time': 1724138535586}], [{'uuid': '1a040000-0000-0000-0000-000000000000', 'rssi': -56, 'accuracy': 4.817547502022513, 'time': 1724138536122}], [{'uuid': '1a040000-0000-0000-0000-000000000000', 'rssi': -57, 'accuracy': 5.639149102972735, 'time': 1724138536630}, {'uuid': '88400000-0000-0000-0000-000000000000', 'rssi': -65, 'accuracy': 19.345173789319468, 'time': 1724138536630}], [{'uuid': '1a040000-0000-0000-0000-000000000000', 'rssi': -67, 'accuracy': 25.958067100628753, 'time': 1724138537368}, {'uuid': '88400000-0000-0000-0000-000000000000', 'rssi': -61, 'accuracy': 10.542056415326362, 'time': 1724138537368}], [{'uuid': '1a040000-0000-0000-0000-000000000000', 'rssi': -60, 'accuracy': 9.027046541095386, 'time': 1724138538032}, {'uuid': '88400000-0000-0000-0000-000000000000', 'rssi': -61, 'accuracy': 10.542056415326362, 'time': 1724138538032}], [{'uuid': '1a040000-0000-0000-0000-000000000000', 'rssi': -62, 'accuracy': 12.296376053275772, 'time': 1724138539078}, {'uuid': '88400000-0000-0000-0000-000000000000', 'rssi': -60, 'accuracy': 9.027046541095386, 'time': 1724138539078}], [{'uuid': '1a040000-0000-0000-0000-000000000000', 'rssi': -67, 'accuracy': 25.958067100628753, 'time': 1724138539713}, {'uuid': '88400000-0000-0000-0000-000000000000', 'rssi': -56, 'accuracy': 4.817547502022513, 'time': 1724138539713}], [{'uuid': '1a040000-0000-0000-0000-000000000000', 'rssi': -62, 'accuracy': 12.296376053275772, 'time': 1724138540315}, {'uuid': '88400000-0000-0000-0000-000000000000', 'rssi': -56, 'accuracy': 4.817547502022513, 'time': 1724138540315}], [{'uuid': '1a040000-0000-0000-0000-000000000000', 'rssi': -62, 'accuracy': 12.296376053275772, 'time': 1724138540831}, {'uuid': '88400000-0000-0000-0000-000000000000', 'rssi': -56, 'accuracy': 4.817547502022513, 'time': 1724138540831}], [{'uuid': '1a040000-0000-0000-0000-000000000000', 'rssi': -63, 'accuracy': 14.323008481499683, 'time': 1724138541355}, {'uuid': '88400000-0000-0000-0000-000000000000', 'rssi': -64, 'accuracy': 16.658868643737616, 'time': 1724138541355}], [{'uuid': '1a040000-0000-0000-0000-000000000000', 'rssi': -64, 'accuracy': 16.658868643737616, 'time': 1724138542337}, {'uuid': '88400000-0000-0000-0000-000000000000', 'rssi': -61, 'accuracy': 10.542056415326362, 'time': 1724138542337}], [{'uuid': '1a040000-0000-0000-0000-000000000000', 'rssi': -63, 'accuracy': 14.323008481499683, 'time': 1724138542967}, {'uuid': '88400000-0000-0000-0000-000000000000', 'rssi': -63, 'accuracy': 14.323008481499683, 'time': 1724138542967}], [{'uuid': '1a040000-0000-0000-0000-000000000000', 'rssi': -71, 'accuracy': 45.78640352029778, 'time': 1724138543494}, {'uuid': '88400000-0000-0000-0000-000000000000', 'rssi': -67, 'accuracy': 25.958067100628753, 'time': 1724138543494}], [{'uuid': '1a040000-0000-0000-0000-000000000000', 'rssi': -62, 'accuracy': 12.296376053275772, 'time': 1724138544085}, {'uuid': '88400000-0000-0000-0000-000000000000', 'rssi': -67, 'accuracy': 25.958067100628753, 'time': 1724138544085}], [{'uuid': '1a040000-0000-0000-0000-000000000000', 'rssi': -62, 'accuracy': 12.296376053275772, 'time': 1724138544654}, {'uuid': '88400000-0000-0000-0000-000000000000', 'rssi': -60, 'accuracy': 9.027046541095386, 'time': 1724138544654}], [{'uuid': '1a040000-0000-0000-0000-000000000000', 'rssi': -62, 'accuracy': 12.296376053275772, 'time': 1724138545175}, {'uuid': '88400000-0000-0000-0000-000000000000', 'rssi': -55, 'accuracy': 4.117249110083256, 'time': 1724138545175}], [{'uuid': '1a040000-0000-0000-0000-000000000000', 'rssi': -62, 'accuracy': 12.296376053275772, 'time': 1724138545807}, {'uuid': '88400000-0000-0000-0000-000000000000', 'rssi': -54, 'accuracy': 3.5220749899226886, 'time': 1724138545807}], [{'uuid': '1a040000-0000-0000-0000-000000000000', 'rssi': -60, 'accuracy': 9.027046541095386, 'time': 1724138546605}, {'uuid': '88400000-0000-0000-0000-000000000000', 'rssi': -53, 'accurac ...
# <class 'list'>

# %%
import matplotlib.pyplot as plt

intervals = []
for i in range(len(beacon_data) - 1):
    current_time = beacon_data[i][0]['time']
    next_time = beacon_data[i+1][0]['time']
    interval = (next_time - current_time) / 1000  # Convert milliseconds to seconds
    intervals.append(interval)
    print(f"Interval between data {i} and {i+1}: {interval:.2f} seconds")

plt.figure(figsize=(10, 5))
plt.plot(range(len(intervals)), intervals, marker='o')
plt.title('Interval Time Between Adjacent Data Points')
plt.xlabel('Data Point Index')
plt.ylabel('Interval (seconds)')
plt.grid(True)
plt.show()

print(f"Average interval: {sum(intervals) / len(intervals):.2f} seconds")
print(f"Minimum interval: {min(intervals):.2f} seconds")
print(f"Maximum interval: {max(intervals):.2f} seconds")
# Out:
# Interval between data 0 and 1: 0.54 seconds
# Interval between data 1 and 2: 0.51 seconds
# Interval between data 2 and 3: 0.74 seconds
# Interval between data 3 and 4: 0.66 seconds
# Interval between data 4 and 5: 1.05 seconds
# Interval between data 5 and 6: 0.64 seconds
# Interval between data 6 and 7: 0.60 seconds
# Interval between data 7 and 8: 0.52 seconds
# Interval between data 8 and 9: 0.52 seconds
# Interval between data 9 and 10: 0.98 seconds
# Interval between data 10 and 11: 0.63 seconds
# Interval between data 11 and 12: 0.53 seconds
# Interval between data 12 and 13: 0.59 seconds
# Interval between data 13 and 14: 0.57 seconds
# Interval between data 14 and 15: 0.52 seconds
# Interval between data 15 and 16: 0.63 seconds
# Interval between data 16 and 17: 0.80 seconds
# Interval between data 17 and 18: 0.63 seconds
# Interval between data 18 and 19: 0.75 seconds
# Interval between data 19 and 20: 0.56 seconds
# Interval between data 20 and 21: 0.90 seconds
# Interval between data 21 and 22: 0.77 seconds
# Interval between data 22 and 23: 0.52 seconds
# Interval between data 23 and 24: 0.80 seconds
# Interval between data 24 and 25: 0.57 seconds
# Interval between data 25 and 26: 0.53 seconds
# Interval between data 26 and 27: 0.70 seconds
# Interval between data 27 and 28: 0.56 seconds
# Interval between data 28 and 29: 0.70 seconds
# Interval between data 29 and 30: 0.53 seconds
# Interval between data 30 and 31: 0.56 seconds
# Interval between data 31 and 32: 0.59 seconds
# Interval between data 32 and 33: 0.67 seconds
# Interval between data 33 and 34: 1.05 seconds
# Interval between data 34 and 35: 0.52 seconds
# Interval between data 35 and 36: 0.52 seconds
# Interval between data 36 and 37: 0.73 seconds
# Interval between data 37 and 38: 0.53 seconds
# Interval between data 38 and 39: 0.53 seconds
# Interval between data 39 and 40: 0.52 seconds
# Interval between data 40 and 41: 0.64 seconds
# Interval between data 41 and 42: 0.63 seconds
# Interval between data 42 and 43: 0.63 seconds
# Interval between data 43 and 44: 1.05 seconds
# Interval between data 44 and 45: 0.60 seconds
# Interval between data 45 and 46: 0.73 seconds
# Interval between data 46 and 47: 0.63 seconds
# Interval between data 47 and 48: 0.53 seconds
# Interval between data 48 and 49: 0.84 seconds
# Interval between data 49 and 50: 0.56 seconds
# Interval between data 50 and 51: 0.63 seconds
# Interval between data 51 and 52: 0.60 seconds
# Interval between data 52 and 53: 0.52 seconds
# Interval between data 53 and 54: 0.53 seconds
# Interval between data 54 and 55: 0.67 seconds
# Interval between data 55 and 56: 0.52 seconds
# Interval between data 56 and 57: 0.63 seconds
# Interval between data 57 and 58: 0.71 seconds
# Interval between data 58 and 59: 0.66 seconds
# Interval between data 59 and 60: 0.63 seconds
# Interval between data 60 and 61: 0.59 seconds
# Interval between data 61 and 62: 0.57 seconds
# Interval between data 62 and 63: 0.52 seconds
# Interval between data 63 and 64: 0.53 seconds
# Interval between data 64 and 65: 0.53 seconds
# Interval between data 65 and 66: 0.63 seconds
# Interval between data 66 and 67: 0.59 seconds
# Interval between data 67 and 68: 0.67 seconds
# Interval between data 68 and 69: 0.73 seconds
# Interval between data 69 and 70: 0.53 seconds
# Interval between data 70 and 71: 0.53 seconds
# Interval between data 71 and 72: 1.01 seconds
# Interval between data 72 and 73: 0.94 seconds
# Interval between data 73 and 74: 0.63 seconds
# Interval between data 74 and 75: 0.63 seconds
# Interval between data 75 and 76: 0.56 seconds
# Interval between data 76 and 77: 0.52 seconds
# Interval between data 77 and 78: 0.53 seconds
# Interval between data 78 and 79: 0.53 seconds
# Interval between data 79 and 80: 0.52 seconds
# Interval between data 80 and 81: 0.94 seconds
# Interval between data 81 and 82: 0.92 seconds
# Interval between data 82 and 83: 0.83 seconds
# Interval between data 83 and 84: 0.56 seconds
# Interval between data 84 and 85: 0.52 seconds
# Interval between data 85 and 86: 0.53 seconds
# Interval between data 86 and 87: 0.52 seconds
# Interval between data 87 and 88: 0.60 seconds
# Interval between data 88 and 89: 0.62 seconds
# Interval between data 89 and 90: 1.16 seconds
# Interval between data 90 and 91: 0.76 seconds
# Interval between data 91 and 92: 0.74 seconds
# Interval between data 92 and 93: 0.59 seconds
# Interval between data 93 and 94: 0.53 seconds
# Interval between data 94 and 95: 0.53 seconds
# Interval between data 95 and 96: 0.63 seconds
# Interval between data 96 and 97: 0.55 seconds
# Interval between data 97 and 98: 0.70 seconds
# Interval between data 98 and 99: 0.66 seconds
# Interval between data 99 and 100: 0.53 seconds
# Interval between data 100 and 101: 0.91 seconds
# Interval between data 101 and 102: 0.87 seconds
# Interval between data 102 and 103: 0.53 seconds
# Interval between data 103 and 104: 0.63 seconds
# Interval between data 104 and 105: 0.52 seconds
# Interval between data 105 and 106: 0.53 seconds
# Interval between data 106 and 107: 0.74 seconds
# Interval between data 107 and 108: 0.64 seconds
# Interval between data 108 and 109: 0.70 seconds
# Interval between data 109 and 110: 0.66 seconds
# Interval between data 110 and 111: 0.53 seconds
# Interval between data 111 and 112: 0.90 seconds
# Interval between data 112 and 113: 0.67 seconds
# Interval between data 113 and 114: 0.52 seconds
# Interval between data 114 and 115: 0.59 seconds
# Interval between data 115 and 116: 0.66 seconds
# Interval between data 116 and 117: 0.53 seconds
# Interval between data 117 and 118: 0.59 seconds
# Interval between data 118 and 119: 0.53 seconds
# Interval between data 119 and 120: 0.53 seconds
# Interval between data 120 and 121: 0.63 seconds
# Interval between data 121 and 122: 0.73 seconds
# Interval between data 122 and 123: 0.54 seconds
# Interval between data 123 and 124: 0.62 seconds
# Interval between data 124 and 125: 0.52 seconds
# Interval between data 125 and 126: 0.77 seconds
# Interval between data 126 and 127: 0.50 seconds
# Interval between data 127 and 128: 0.97 seconds
# Interval between data 128 and 129: 0.53 seconds
# Interval between data 129 and 130: 0.52 seconds
# Interval between data 130 and 131: 0.60 seconds
# Interval between data 131 and 132: 0.63 seconds
# Interval between data 132 and 133: 0.53 seconds
# Interval between data 133 and 134: 0.55 seconds
# Interval between data 134 and 135: 0.53 seconds
# Interval between data 135 and 136: 0.60 seconds
# Interval between data 136 and 137: 0.52 seconds
# Interval between data 137 and 138: 0.53 seconds
# Interval between data 138 and 139: 0.55 seconds
# Interval between data 139 and 140: 0.53 seconds
# Interval between data 140 and 141: 0.63 seconds
# Interval between data 141 and 142: 0.53 seconds
# Interval between data 142 and 143: 0.60 seconds
# Interval between data 143 and 144: 0.66 seconds
# Interval between data 144 and 145: 0.52 seconds
# Interval between data 145 and 146: 0.60 seconds
# Interval between data 146 and 147: 0.52 seconds
# Interval between data 147 and 148: 0.64 seconds
# Interval between data 148 and 149: 0.52 seconds
# Interval between data 149 and 150: 0.66 seconds
# Interval between data 150 and 151: 0.53 seconds
# Interval between data 151 and 152: 0.52 seconds
# Interval between data 152 and 153: 0.53 seconds
# Interval between data 153 and 154: 0.64 seconds
# Interval between data 154 and 155: 0.73 seconds
# Interval between data 155 and 156: 0.53 seconds
# Interval between data 156 and 157: 0.52 seconds
# Interval between data 157 and 158: 0.53 seconds
# Interval between data 158 and 159: 0.62 seconds
# Interval between data 159 and 160: 0.52 seconds
# Interval between data 160 and 161: 0.64 seconds
# Interval between data 161 and 162: 0.63 seconds
# Interval between data 162 and 163: 0.54 seconds
# Interval between data 163 and 164: 0.58 seconds
# Interval between data 164 and 165: 0.52 seconds
# Interval between data 165 and 166: 0.67 seconds
# Interval between data 166 and 167: 0.60 seconds
# Interval between data 167 and 168: 0.53 seconds
# Interval between data 168 and 169: 0.55 seconds
# Interval between data 169 and 170: 0.52 seconds
# Interval between data 170 and 171: 0.74 seconds
# Interval between data 171 and 172: 0.71 seconds
# Interval between data 172 and 173: 0.63 seconds
# Interval between data 173 and 174: 0.55 seconds
# Interval between data 174 and 175: 0.71 seconds
# Interval between data 175 and 176: 0.56 seconds
# Interval between data 176 and 177: 0.52 seconds
# Interval between data 177 and 178: 0.52 seconds
# Interval between data 178 and 179: 0.74 seconds
# Interval between data 179 and 180: 0.70 seconds
# Interval between data 180 and 181: 0.52 seconds
# Interval between data 181 and 182: 0.67 seconds
# Interval between data 182 and 183: 0.63 seconds
# Interval between data 183 and 184: 0.52 seconds
# Interval between data 184 and 185: 0.70 seconds
# Interval between data 185 and 186: 0.77 seconds
# Interval between data 186 and 187: 0.52 seconds
# Interval between data 187 and 188: 0.63 seconds
# Interval between data 188 and 189: 0.95 seconds
# Interval between data 189 and 190: 0.59 seconds
# Interval between data 190 and 191: 0.56 seconds
# Interval between data 191 and 192: 0.53 seconds
# Interval between data 192 and 193: 0.52 seconds
# Interval between data 193 and 194: 0.52 seconds
# Interval between data 194 and 195: 0.52 seconds
# Interval between data 195 and 196: 0.60 seconds
# Interval between data 196 and 197: 0.56 seconds
# Interval between data 197 and 198: 0.62 seconds
# Interval between data 198 and 199: 0.54 seconds
# Interval between data 199 and 200: 0.80 seconds
# Interval between data 200 and 201: 0.64 seconds
# Interval between data 201 and 202: 0.84 seconds
# Interval between data 202 and 203: 0.62 seconds
# Interval between data 203 and 204: 0.53 seconds
# Interval between data 204 and 205: 0.52 seconds
# Interval between data 205 and 206: 0.56 seconds
# Interval between data 206 and 207: 0.52 seconds
# Interval between data 207 and 208: 0.53 seconds
# Interval between data 208 and 209: 0.53 seconds
# Interval between data 209 and 210: 0.52 seconds
# Interval between data 210 and 211: 0.60 seconds
# Interval between data 211 and 212: 0.53 seconds
# Interval between data 212 and 213: 0.55 seconds
# Interval between data 213 and 214: 0.53 seconds
# Interval between data 214 and 215: 0.60 seconds
# Interval between data 215 and 216: 0.53 seconds
# Interval between data 216 and 217: 0.67 seconds
# Interval between data 217 and 218: 0.63 seconds
# Interval between data 218 and 219: 0.63 seconds
# Interval between data 219 and 220: 0.59 seconds
# Interval between data 220 and 221: 0.56 seconds
# Interval between data 221 and 222: 0.70 seconds
# Interval between data 222 and 223: 0.57 seconds
# Interval between data 223 and 224: 0.73 seconds
# Interval between data 224 and 225: 0.62 seconds
# Interval between data 225 and 226: 0.60 seconds
# Interval between data 226 and 227: 0.56 seconds
# Interval between data 227 and 228: 0.53 seconds
# Interval between data 228 and 229: 0.52 seconds
# Interval between data 229 and 230: 0.52 seconds
# Interval between data 230 and 231: 0.52 seconds
# Interval between data 231 and 232: 0.64 seconds
# Interval between data 232 and 233: 0.60 seconds
# Interval between data 233 and 234: 0.52 seconds
# Interval between data 234 and 235: 0.53 seconds
# Interval between data 235 and 236: 0.56 seconds
# Interval between data 236 and 237: 0.59 seconds
# Interval between data 237 and 238: 0.55 seconds
# Interval between data 238 and 239: 0.53 seconds
# Interval between data 239 and 240: 0.52 seconds
# Interval between data 240 and 241: 0.64 seconds
# Interval between data 241 and 242: 0.52 seconds
# Interval between data 242 and 243: 0.70 seconds
# Interval between data 243 and 244: 0.63 seconds
# Interval between data 244 and 245: 0.84 seconds
# Interval between data 245 and 246: 0.56 seconds
# Interval between data 246 and 247: 0.52 seconds
# Interval between data 247 and 248: 0.81 seconds
# Interval between data 248 and 249: 0.66 seconds
# Interval between data 249 and 250: 0.52 seconds
# Interval between data 250 and 251: 0.70 seconds
# Interval between data 251 and 252: 0.67 seconds
# Interval between data 252 and 253: 0.60 seconds
# Interval between data 253 and 254: 0.52 seconds
# Interval between data 254 and 255: 0.53 seconds
# Interval between data 255 and 256: 0.52 seconds
# Interval between data 256 and 257: 0.53 seconds
# Interval between data 257 and 258: 0.84 seconds
# Interval between data 258 and 259: 0.56 seconds
# Interval between data 259 and 260: 0.53 seconds
# Interval between data 260 and 261: 0.73 seconds
# Interval between data 261 and 262: 0.52 seconds
# Interval between data 262 and 263: 0.74 seconds
# Interval between data 263 and 264: 0.63 seconds
# Interval between data 264 and 265: 0.60 seconds
# Average interval: 0.62 seconds
# Minimum interval: 0.50 seconds
# Maximum interval: 1.16 seconds

# %%
# Print RSSI values between adjacent lists in beacon_data
import matplotlib.pyplot as plt

# Create a dictionary to store RSSI values for each UUID
uuid_rssi_data = {}

# Collect RSSI data for each UUID
for data_list in beacon_data:
    for beacon in data_list:
        uuid = beacon['uuid']
        rssi = beacon['rssi']
        time = beacon['time'] / 1000  # Convert milliseconds to seconds
        
        if uuid not in uuid_rssi_data:
            uuid_rssi_data[uuid] = {'time': [], 'rssi': []}
        
        uuid_rssi_data[uuid]['time'].append(time)
        uuid_rssi_data[uuid]['rssi'].append(rssi)

# Plot RSSI changes for each UUID
plt.figure(figsize=(12, 18))

for uuid, data in uuid_rssi_data.items():
    plt.plot(data['time'], data['rssi'], label=f'UUID: {uuid}')

plt.title('RSSI Changes Over Time for Different UUIDs')
plt.xlabel('Time (seconds)')
plt.ylabel('RSSI')
plt.legend()
plt.grid(True)

# Add more detail to y-axis
plt.yticks(range(min(min(data['rssi']) for data in uuid_rssi_data.values()) - 5,
                 max(max(data['rssi']) for data in uuid_rssi_data.values()) + 5,
                 2))  # Increment by 2 for more detail

plt.show()

# Print summary statistics
for uuid, data in uuid_rssi_data.items():
    print(f"UUID: {uuid}")
    print(f"  Number of data points: {len(data['rssi'])}")
    print(f"  Min RSSI: {min(data['rssi'])}")
    print(f"  Max RSSI: {max(data['rssi'])}")
    print(f"  Average RSSI: {sum(data['rssi']) / len(data['rssi']):.2f}")
    print()
# Out:
# UUID: 1a040000-0000-0000-0000-000000000000
#   Number of data points: 266
#   Min RSSI: -77
#   Max RSSI: 127
#   Average RSSI: -55.35
#
# UUID: 88400000-0000-0000-0000-000000000000
#   Number of data points: 264
#   Min RSSI: -76
#   Max RSSI: 127
#   Average RSSI: -54.88

# %%
def get_acc_strongest_beacons(beacon_data, beacon_coords):
    strongest_uuids, signal_strengths = process_beacon_data(beacon_data)
    return [beacon_coords[uuid] for uuid in strongest_uuids]

def rssi_to_distance(rssi):
    txPower = -59
    n = 2.0
    return 10 ** ((txPower - rssi) / (10 * n))

# %%
import matplotlib.pyplot as plt

# %%
# Plot the dynamic positions

plt.figure(figsize=(10, 6))

plt.scatter(actual_coords['x'], actual_coords['y'], c='green', label='Actual Coordinates')
plt.scatter(estimated_coords['x'], estimated_coords['y'], c='red', label='Estimated Coordinates')

plt.title('Estimated vs Actual Coordinates')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 5
#       1 # Plot the dynamic positions
#       3 plt.figure(figsize=(10, 6))
# ----> 5 plt.scatter(actual_coords['x'], actual_coords['y'], c='green', label='Actual Coordinates')
#       6 plt.scatter(estimated_coords['x'], estimated_coords['y'], c='red', label='Estimated Coordinates')
#       8 plt.title('Estimated vs Actual Coordinates')
#
# KeyError: 'x'
